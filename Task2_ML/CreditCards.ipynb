# %%
import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import ADASYN
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import precision_score, recall_score, f1_score

# %%
df = pd.read_csv('creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# Большинство признаков (V1 - V28) имеют один порядок значений, а Time и Amount имеют гораздо больший порядок, а значит, нужно будет привести данные к единому порядку, чтобы избежать переобучения (в противном случае небольшое изменение в этих фичах будет приводить к существенному изменению прогноза)

# %%
df.Class.nunique()
# Out:
# 2

# %% [markdown]
# В задаче у нас 2 класса - мошеннические операции (1) и немошеннические (0)

# %%
per_fraud = len(df[df.Class == 1]) / len(df) * 100

print(f'Мошеннических операций {per_fraud} %')
# Out:
# Мошеннических операций 0.1727485630620034 %

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df_new = df[~df.duplicated()]

# %% [markdown]
# убрали дубликаты в данных

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# исходя из матрицы, проблемы мультиколлинеарности возникнуть не должно, можем оставить все фичи

# %% [markdown]
# посмотрим на зависимости фичей друг от друга - возможно сможем получить новые признаки
# принципальная разница у нас в признаках Time, Amount и V1-V28 (потому что они получены из одного источника)

# %%
sns.scatterplot(data=df, x="Time", y="V1", hue="Class")
# Out:
# <Axes: xlabel='Time', ylabel='V1'>

# %%
sns.scatterplot(data=df, x="Time", y="Amount", hue="Class")
# Out:
# <Axes: xlabel='Time', ylabel='Amount'>

# %%
sns.scatterplot(data=df, x="V1", y="Amount", hue="Class")
# Out:
# <Axes: xlabel='V1', ylabel='Amount'>

# %%
sns.scatterplot(data=df, x="V1", y="V11", hue="Class")
# Out:
# <Axes: xlabel='V1', ylabel='V11'>

# %%
sns.scatterplot(data=df, x="V2", y="V15", hue="Class")
# Out:
# <Axes: xlabel='V2', ylabel='V15'>

# %% [markdown]
# по графикам можно сделать следующий вывод: по фичам Time и Amount качественно классы разделить возможным в принципе не представляется - вся полезная информация лежит внутри V1 - V28, но удалять Time и Amount на всякий случай не будем (больше информации - лучше)
#
# качественного feature engineering в этой задаче провести не получится (так же, как и проверить данные на выбросы), потому что неизвестен смысл V1 - V28, так что будет работать дальше с тем что имеем (нет пропусков - и на том спасибо...)

# %%
X = df.iloc[:, :-1]
y = df.Class

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=84, stratify=y)

# %% [markdown]
# будем идти по мере усложнения моделей (причём как без сэмплирования, так и с ним + везде стандартизируем данные), а по метрикам будем единовременно смотреть precision и recall и f2 метрику (почему не f1 - потому что важнее всё же отделять мошеннические операции)
#
# соответственно порядок действий следующий
#
# 1) KNN
# 2) KNN с сэмплированием
# 3) Логистическая регрессия (исключительно без сэмплирования, потому что на ней сэмплирование даёт некорректный результат)
# 4) Рандомный лес (простые деревья переобучатся, тк много фичей, а лес в целом должен с задачей справиться)
# 5) Рандомный лес с сэмплированием
#
# критерии итогового выбора модели - максимальные precision и recall (приоритет отдаётся precision, тк опять же - важнее отделять мошеннические операции)
#
# SVC чисто из принципа использован не будет, потому что на больших датасетах (как наш) он очень долго будет работать
#
# Тут обязательно нужно делать пересэмплирование, тк мош. операций мало

# %%
# для f2 score

betta = 2

f2_lambda = lambda pr, re, betta: (1 + np.power(betta, 2)) * (pr * re) / (np.power(betta, 2) * pr + re)

# %%
# соседей ставим поменьше, тк один из классов небольшой сам по себе

from sklearn.pipeline import Pipeline

pipe = Pipeline([('scaler', StandardScaler()), 
                 ('clf', KNeighborsClassifier(n_neighbors=5))])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f'precision: {precision}, recall: {recall}, f2-score: {f2_lambda(precision, recall, betta)}')
# Out:
# precision: 0.9197080291970803, recall: 0.7777777777777778, f2-score: 0.802547770700637

# %%
# честно сказать, не нашёл, как в sklearn-овский Pipeline вносить сэмплирование, 
# поэтому каждый раз буду 💫импортировать заново💫  

from imblearn.pipeline import Pipeline 

pipe = Pipeline([('scaler', StandardScaler()), 
                 ('smote', ADASYN(random_state=84)),
                 ('clf', KNeighborsClassifier(n_neighbors=5))])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f'precision: {precision}, recall: {recall}, f2-score: {f2_lambda(precision, recall, betta)}')
# Out:
# precision: 0.4473684210526316, recall: 0.8395061728395061, f2-score: 0.7142857142857142

# %%
# class_weight = 'balanced' ставится для использования модели с несбалансированными данными

from sklearn.pipeline import Pipeline

pipe = Pipeline([('scaler', StandardScaler()), 
                 ('clf', LogisticRegression(class_weight = 'balanced', n_jobs=-1))])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f'precision: {precision}, recall: {recall}, f2-score: {f2_lambda(precision, recall, betta)}')
# Out:
# precision: 0.060920016576875256, recall: 0.9074074074074074, f2-score: 0.24011760862463252

# %%
pipe = Pipeline([('scaler', StandardScaler()), 
                 ('clf', RandomForestClassifier(class_weight = 'balanced', n_jobs=-1))])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f'precision: {precision}, recall: {recall}, f2-score: {f2_lambda(precision, recall, betta)}')
# Out:
# precision: 0.9384615384615385, recall: 0.7530864197530864, f2-score: 0.7840616966580978

# %%
from imblearn.pipeline import Pipeline 

pipe = Pipeline([('scaler', StandardScaler()),
                 ('smote', ADASYN(random_state=84)),
                 ('clf', RandomForestClassifier(n_jobs=-1))])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f'precision: {precision}, recall: {recall}, f2-score: {f2_lambda(precision, recall, betta)}')
# Out:
# precision: 0.8896551724137931, recall: 0.7962962962962963, f2-score: 0.8133669609079444

# %% [markdown]
# по итогу по метрикам два лидера - KNeighborsClassifier и RandomForestClassifier без сэмплирования
#
# думаю, здесь лучше оставиться на KNeighborsClassifier, поскольку у него больший precision (а мош. операции отделять важнее)
